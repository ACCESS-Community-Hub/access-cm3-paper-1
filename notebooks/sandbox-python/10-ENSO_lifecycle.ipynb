# %% [markdown]
# # ENSO_lifecycle: temporal evolution of SST anomalies in the central equatorial Pacific
#
# Computes the temporal root mean square error (RMSE) of sea surface temperature anomalies (SSTA) in the Niño3.4 region (horizontal average over 5°S–5°N, 170°W–120°W) between model and observations. The analysis spans 6 years centred on ENSO peak years to evaluate the ability of the model to capture the full lifecycle of ENSO events, including onset, peak, and decay phases.
#
# ## Datasets Used for Temporal Evolution Comparison
# The following reference datasets are employed to evaluate the ENSO lifecycle in model simulations:
#
# - **TropFlux** (1979–2018): The primary dataset for comparison, offering accurate surface fluxes and anomalies for tropical climate studies.
#
# ## Additional datasets include:
#
# - **20CRv2** (1871–2012): A historical reanalysis dataset reconstructing global atmospheric conditions using surface pressure observations.
# - **ERA-Interim** (1979–2018): A widely used reanalysis product providing consistent, high-resolution estimates of atmospheric and surface variables.
# - **ERSSTv5** (1854–2018): A globally gridded SST anomaly dataset optimised for long-term climate monitoring and ENSO analysis.
# - **HadISST** (1870–2018): A comprehensive dataset of SST and sea ice, blending historical observations with reconstructions.
# - **NCEP2** (1979–2018): A second-generation reanalysis dataset delivering improved global atmospheric and surface data.

# %% [markdown]
# ## Dask Cluster
#
# Start a cluster with multiple cores

# %%
from dask.distributed import Client, progress
client = Client()
client
# Out:
# <Client: 'tcp://127.0.0.1:38247' processes=7 threads=28, memory=126.00 GiB>
# 2025-09-02 10:02:16,334 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-c60ba13cf04eb4532036e60a1854fea7', 1, 2, 1) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-c60ba13cf04eb4532036e60a1854fea7', 1, 2, 1)->('rechunk-merge-fe497c6ff29d9da5ff745fbde117036f', 1, 2, 1))
# new run_spec: Alias(('getitem-c60ba13cf04eb4532036e60a1854fea7', 1, 2, 1)->('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 1, 2, 1))
# old dependencies: {('rechunk-merge-fe497c6ff29d9da5ff745fbde117036f', 1, 2, 1)}
# new dependencies: frozenset({('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 1, 2, 1)})
#
# 2025-09-02 10:02:16,335 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-40021c1abf1595b70860a6e0b8f15234', 1, 2, 1) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-40021c1abf1595b70860a6e0b8f15234', 1, 2, 1)->('rechunk-merge-e01feae861cd8f1643cd0bde2cc99126', 1, 2, 1))
# new run_spec: Alias(('getitem-40021c1abf1595b70860a6e0b8f15234', 1, 2, 1)->('rechunk-merge-rechunk-split-getitem-40021c1abf1595b70860a6e0b8f15234', 1, 2, 1))
# old dependencies: {('rechunk-merge-e01feae861cd8f1643cd0bde2cc99126', 1, 2, 1)}
# new dependencies: frozenset({('rechunk-merge-rechunk-split-getitem-40021c1abf1595b70860a6e0b8f15234', 1, 2, 1)})
#
# 2025-09-02 10:02:25,165 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-40021c1abf1595b70860a6e0b8f15234', 2, 1, 1) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-40021c1abf1595b70860a6e0b8f15234', 2, 1, 1)->('rechunk-merge-e01feae861cd8f1643cd0bde2cc99126', 2, 1, 1))
# new run_spec: Alias(('getitem-40021c1abf1595b70860a6e0b8f15234', 2, 1, 1)->('rechunk-merge-rechunk-split-getitem-40021c1abf1595b70860a6e0b8f15234', 2, 1, 1))
# old dependencies: {('rechunk-merge-e01feae861cd8f1643cd0bde2cc99126', 2, 1, 1)}
# new dependencies: frozenset({('rechunk-merge-rechunk-split-getitem-40021c1abf1595b70860a6e0b8f15234', 2, 1, 1)})
#
# 2025-09-02 10:02:25,166 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-c60ba13cf04eb4532036e60a1854fea7', 2, 1, 1) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-c60ba13cf04eb4532036e60a1854fea7', 2, 1, 1)->('rechunk-merge-fe497c6ff29d9da5ff745fbde117036f', 2, 1, 1))
# new run_spec: Alias(('getitem-c60ba13cf04eb4532036e60a1854fea7', 2, 1, 1)->('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 2, 1, 1))
# old dependencies: {('rechunk-merge-fe497c6ff29d9da5ff745fbde117036f', 2, 1, 1)}
# new dependencies: frozenset({('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 2, 1, 1)})
#
# 2025-09-02 10:02:35,382 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-40021c1abf1595b70860a6e0b8f15234', 6.9, 2, 1) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-40021c1abf1595b70860a6e0b8f15234', 6.9, 2, 1)->('rechunk-merge-rechunk-split-getitem-40021c1abf1595b70860a6e0b8f15234', 6.9, 2, 1))
# new run_spec: <Task ('getitem-40021c1abf1595b70860a6e0b8f15234', 6.9, 2, 1) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-40021c1abf1595b70860a6e0b8f15234', 6.9, 2, 1)}
# new dependencies: frozenset({('rechunk-merge-e01feae861cd8f1643cd0bde2cc99126', 7, 2, 1)})
#
# 2025-09-02 10:02:35,383 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-c60ba13cf04eb4532036e60a1854fea7', 6.9, 2, 1) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-c60ba13cf04eb4532036e60a1854fea7', 6.9, 2, 1)->('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 6.9, 2, 1))
# new run_spec: <Task ('getitem-c60ba13cf04eb4532036e60a1854fea7', 6.9, 2, 1) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 6.9, 2, 1)}
# new dependencies: frozenset({('rechunk-merge-fe497c6ff29d9da5ff745fbde117036f', 7, 2, 1)})
#
# 2025-09-02 10:02:43,375 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-40021c1abf1595b70860a6e0b8f15234', 7.9, 2, 2) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-40021c1abf1595b70860a6e0b8f15234', 7.9, 2, 2)->('rechunk-merge-rechunk-split-getitem-40021c1abf1595b70860a6e0b8f15234', 7.9, 2, 2))
# new run_spec: <Task ('getitem-40021c1abf1595b70860a6e0b8f15234', 7.9, 2, 2) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-40021c1abf1595b70860a6e0b8f15234', 7.9, 2, 2)}
# new dependencies: frozenset({('rechunk-merge-e01feae861cd8f1643cd0bde2cc99126', 8, 2, 2)})
#
# 2025-09-02 10:02:43,376 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-c60ba13cf04eb4532036e60a1854fea7', 7.9, 2, 2) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-c60ba13cf04eb4532036e60a1854fea7', 7.9, 2, 2)->('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 7.9, 2, 2))
# new run_spec: <Task ('getitem-c60ba13cf04eb4532036e60a1854fea7', 7.9, 2, 2) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 7.9, 2, 2)}
# new dependencies: frozenset({('rechunk-merge-fe497c6ff29d9da5ff745fbde117036f', 8, 2, 2)})
#
# 2025-09-02 10:02:52,762 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-40021c1abf1595b70860a6e0b8f15234', 7.9, 2, 2) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-40021c1abf1595b70860a6e0b8f15234', 7.9, 2, 2)->('rechunk-merge-rechunk-split-getitem-40021c1abf1595b70860a6e0b8f15234', 7.9, 2, 2))
# new run_spec: <Task ('getitem-40021c1abf1595b70860a6e0b8f15234', 7.9, 2, 2) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-40021c1abf1595b70860a6e0b8f15234', 7.9, 2, 2)}
# new dependencies: frozenset({('rechunk-merge-e01feae861cd8f1643cd0bde2cc99126', 8, 2, 2)})
#
# 2025-09-02 10:02:52,763 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-c60ba13cf04eb4532036e60a1854fea7', 7.9, 2, 2) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-c60ba13cf04eb4532036e60a1854fea7', 7.9, 2, 2)->('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 7.9, 2, 2))
# new run_spec: <Task ('getitem-c60ba13cf04eb4532036e60a1854fea7', 7.9, 2, 2) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 7.9, 2, 2)}
# new dependencies: frozenset({('rechunk-merge-fe497c6ff29d9da5ff745fbde117036f', 8, 2, 2)})
#
# 2025-09-02 10:02:59,855 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-40021c1abf1595b70860a6e0b8f15234', 7.9, 2, 2) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-40021c1abf1595b70860a6e0b8f15234', 7.9, 2, 2)->('rechunk-merge-rechunk-split-getitem-40021c1abf1595b70860a6e0b8f15234', 7.9, 2, 2))
# new run_spec: <Task ('getitem-40021c1abf1595b70860a6e0b8f15234', 7.9, 2, 2) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-40021c1abf1595b70860a6e0b8f15234', 7.9, 2, 2)}
# new dependencies: frozenset({('rechunk-merge-e01feae861cd8f1643cd0bde2cc99126', 8, 2, 2)})
#
# 2025-09-02 10:02:59,857 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-c60ba13cf04eb4532036e60a1854fea7', 7.9, 2, 2) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-c60ba13cf04eb4532036e60a1854fea7', 7.9, 2, 2)->('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 7.9, 2, 2))
# new run_spec: <Task ('getitem-c60ba13cf04eb4532036e60a1854fea7', 7.9, 2, 2) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 7.9, 2, 2)}
# new dependencies: frozenset({('rechunk-merge-fe497c6ff29d9da5ff745fbde117036f', 8, 2, 2)})
#
# 2025-09-02 10:03:06,789 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-c60ba13cf04eb4532036e60a1854fea7', 9.9, 0, 2) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-c60ba13cf04eb4532036e60a1854fea7', 9.9, 0, 2)->('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 9.9, 0, 2))
# new run_spec: <Task ('getitem-c60ba13cf04eb4532036e60a1854fea7', 9.9, 0, 2) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 9.9, 0, 2)}
# new dependencies: frozenset({('rechunk-merge-fe497c6ff29d9da5ff745fbde117036f', 10, 0, 2)})
#
# 2025-09-02 10:03:06,790 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-40021c1abf1595b70860a6e0b8f15234', 9.9, 0, 2) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-40021c1abf1595b70860a6e0b8f15234', 9.9, 0, 2)->('rechunk-merge-rechunk-split-getitem-40021c1abf1595b70860a6e0b8f15234', 9.9, 0, 2))
# new run_spec: <Task ('getitem-40021c1abf1595b70860a6e0b8f15234', 9.9, 0, 2) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-40021c1abf1595b70860a6e0b8f15234', 9.9, 0, 2)}
# new dependencies: frozenset({('rechunk-merge-e01feae861cd8f1643cd0bde2cc99126', 10, 0, 2)})
#
# 2025-09-02 10:03:12,977 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-c60ba13cf04eb4532036e60a1854fea7', 10.9, 2, 2) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-c60ba13cf04eb4532036e60a1854fea7', 10.9, 2, 2)->('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 10.9, 2, 2))
# new run_spec: <Task ('getitem-c60ba13cf04eb4532036e60a1854fea7', 10.9, 2, 2) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 10.9, 2, 2)}
# new dependencies: frozenset({('rechunk-merge-fe497c6ff29d9da5ff745fbde117036f', 11, 2, 2)})
#
# 2025-09-02 10:03:12,978 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-40021c1abf1595b70860a6e0b8f15234', 10.9, 2, 2) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-40021c1abf1595b70860a6e0b8f15234', 10.9, 2, 2)->('rechunk-merge-rechunk-split-getitem-40021c1abf1595b70860a6e0b8f15234', 10.9, 2, 2))
# new run_spec: <Task ('getitem-40021c1abf1595b70860a6e0b8f15234', 10.9, 2, 2) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-40021c1abf1595b70860a6e0b8f15234', 10.9, 2, 2)}
# new dependencies: frozenset({('rechunk-merge-e01feae861cd8f1643cd0bde2cc99126', 11, 2, 2)})
#
# 2025-09-02 10:03:19,878 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-c60ba13cf04eb4532036e60a1854fea7', 9.9, 0, 2) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-c60ba13cf04eb4532036e60a1854fea7', 9.9, 0, 2)->('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 9.9, 0, 2))
# new run_spec: <Task ('getitem-c60ba13cf04eb4532036e60a1854fea7', 9.9, 0, 2) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 9.9, 0, 2)}
# new dependencies: frozenset({('rechunk-merge-fe497c6ff29d9da5ff745fbde117036f', 10, 0, 2)})
#
# 2025-09-02 10:03:19,879 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-40021c1abf1595b70860a6e0b8f15234', 9, 0, 2) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-40021c1abf1595b70860a6e0b8f15234', 9, 0, 2)->('rechunk-merge-e01feae861cd8f1643cd0bde2cc99126', 9, 0, 2))
# new run_spec: Alias(('getitem-40021c1abf1595b70860a6e0b8f15234', 9, 0, 2)->('rechunk-merge-rechunk-split-getitem-40021c1abf1595b70860a6e0b8f15234', 9, 0, 2))
# old dependencies: {('rechunk-merge-e01feae861cd8f1643cd0bde2cc99126', 9, 0, 2)}
# new dependencies: frozenset({('rechunk-merge-rechunk-split-getitem-40021c1abf1595b70860a6e0b8f15234', 9, 0, 2)})
#
# 2025-09-02 10:03:24,995 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-40021c1abf1595b70860a6e0b8f15234', 13.9, 2, 2) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-40021c1abf1595b70860a6e0b8f15234', 13.9, 2, 2)->('rechunk-merge-rechunk-split-getitem-40021c1abf1595b70860a6e0b8f15234', 13.9, 2, 2))
# new run_spec: <Task ('getitem-40021c1abf1595b70860a6e0b8f15234', 13.9, 2, 2) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-40021c1abf1595b70860a6e0b8f15234', 13.9, 2, 2)}
# new dependencies: frozenset({('rechunk-merge-e01feae861cd8f1643cd0bde2cc99126', 14, 2, 2)})
#
# 2025-09-02 10:03:24,996 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-c60ba13cf04eb4532036e60a1854fea7', 13.9, 2, 2) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-c60ba13cf04eb4532036e60a1854fea7', 13.9, 2, 2)->('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 13.9, 2, 2))
# new run_spec: <Task ('getitem-c60ba13cf04eb4532036e60a1854fea7', 13.9, 2, 2) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 13.9, 2, 2)}
# new dependencies: frozenset({('rechunk-merge-fe497c6ff29d9da5ff745fbde117036f', 14, 2, 2)})
#
# 2025-09-02 10:03:32,443 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-c60ba13cf04eb4532036e60a1854fea7', 15.9, 0, 2) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-c60ba13cf04eb4532036e60a1854fea7', 15.9, 0, 2)->('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 15.9, 0, 2))
# new run_spec: <Task ('getitem-c60ba13cf04eb4532036e60a1854fea7', 15.9, 0, 2) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 15.9, 0, 2)}
# new dependencies: frozenset({('rechunk-merge-fe497c6ff29d9da5ff745fbde117036f', 16, 0, 2)})
#
# 2025-09-02 10:03:32,444 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-40021c1abf1595b70860a6e0b8f15234', 15.9, 0, 2) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-40021c1abf1595b70860a6e0b8f15234', 15.9, 0, 2)->('rechunk-merge-rechunk-split-getitem-40021c1abf1595b70860a6e0b8f15234', 15.9, 0, 2))
# new run_spec: <Task ('getitem-40021c1abf1595b70860a6e0b8f15234', 15.9, 0, 2) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-40021c1abf1595b70860a6e0b8f15234', 15.9, 0, 2)}
# new dependencies: frozenset({('rechunk-merge-e01feae861cd8f1643cd0bde2cc99126', 16, 0, 2)})
#
# 2025-09-02 10:03:37,678 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-40021c1abf1595b70860a6e0b8f15234', 14.9, 1, 1) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-40021c1abf1595b70860a6e0b8f15234', 14.9, 1, 1)->('rechunk-merge-rechunk-split-getitem-40021c1abf1595b70860a6e0b8f15234', 14.9, 1, 1))
# new run_spec: <Task ('getitem-40021c1abf1595b70860a6e0b8f15234', 14.9, 1, 1) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-40021c1abf1595b70860a6e0b8f15234', 14.9, 1, 1)}
# new dependencies: frozenset({('rechunk-merge-e01feae861cd8f1643cd0bde2cc99126', 15, 1, 1)})
#
# 2025-09-02 10:03:37,678 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-c60ba13cf04eb4532036e60a1854fea7', 14.9, 1, 1) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-c60ba13cf04eb4532036e60a1854fea7', 14.9, 1, 1)->('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 14.9, 1, 1))
# new run_spec: <Task ('getitem-c60ba13cf04eb4532036e60a1854fea7', 14.9, 1, 1) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 14.9, 1, 1)}
# new dependencies: frozenset({('rechunk-merge-fe497c6ff29d9da5ff745fbde117036f', 15, 1, 1)})
#
# 2025-09-02 10:03:43,633 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-c60ba13cf04eb4532036e60a1854fea7', 15.9, 0, 2) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-c60ba13cf04eb4532036e60a1854fea7', 15.9, 0, 2)->('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 15.9, 0, 2))
# new run_spec: <Task ('getitem-c60ba13cf04eb4532036e60a1854fea7', 15.9, 0, 2) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 15.9, 0, 2)}
# new dependencies: frozenset({('rechunk-merge-fe497c6ff29d9da5ff745fbde117036f', 16, 0, 2)})
#
# 2025-09-02 10:03:43,633 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-40021c1abf1595b70860a6e0b8f15234', 15.9, 0, 2) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-40021c1abf1595b70860a6e0b8f15234', 15.9, 0, 2)->('rechunk-merge-rechunk-split-getitem-40021c1abf1595b70860a6e0b8f15234', 15.9, 0, 2))
# new run_spec: <Task ('getitem-40021c1abf1595b70860a6e0b8f15234', 15.9, 0, 2) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-40021c1abf1595b70860a6e0b8f15234', 15.9, 0, 2)}
# new dependencies: frozenset({('rechunk-merge-e01feae861cd8f1643cd0bde2cc99126', 16, 0, 2)})
#
# 2025-09-02 10:03:50,286 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-c60ba13cf04eb4532036e60a1854fea7', 15.9, 0, 2) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-c60ba13cf04eb4532036e60a1854fea7', 15.9, 0, 2)->('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 15.9, 0, 2))
# new run_spec: <Task ('getitem-c60ba13cf04eb4532036e60a1854fea7', 15.9, 0, 2) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 15.9, 0, 2)}
# new dependencies: frozenset({('rechunk-merge-fe497c6ff29d9da5ff745fbde117036f', 16, 0, 2)})
#
# 2025-09-02 10:03:50,286 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-40021c1abf1595b70860a6e0b8f15234', 15.9, 0, 2) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-40021c1abf1595b70860a6e0b8f15234', 15.9, 0, 2)->('rechunk-merge-rechunk-split-getitem-40021c1abf1595b70860a6e0b8f15234', 15.9, 0, 2))
# new run_spec: <Task ('getitem-40021c1abf1595b70860a6e0b8f15234', 15.9, 0, 2) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-40021c1abf1595b70860a6e0b8f15234', 15.9, 0, 2)}
# new dependencies: frozenset({('rechunk-merge-e01feae861cd8f1643cd0bde2cc99126', 16, 0, 2)})
#
# 2025-09-02 10:03:58,329 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-c60ba13cf04eb4532036e60a1854fea7', 18.9, 1, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-c60ba13cf04eb4532036e60a1854fea7', 18.9, 1, 0)->('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 18.9, 1, 0))
# new run_spec: <Task ('getitem-c60ba13cf04eb4532036e60a1854fea7', 18.9, 1, 0) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 18.9, 1, 0)}
# new dependencies: frozenset({('rechunk-merge-fe497c6ff29d9da5ff745fbde117036f', 19, 1, 0)})
#
# 2025-09-02 10:03:58,329 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-40021c1abf1595b70860a6e0b8f15234', 18.9, 1, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-40021c1abf1595b70860a6e0b8f15234', 18.9, 1, 0)->('rechunk-merge-rechunk-split-getitem-40021c1abf1595b70860a6e0b8f15234', 18.9, 1, 0))
# new run_spec: <Task ('getitem-40021c1abf1595b70860a6e0b8f15234', 18.9, 1, 0) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-40021c1abf1595b70860a6e0b8f15234', 18.9, 1, 0)}
# new dependencies: frozenset({('rechunk-merge-e01feae861cd8f1643cd0bde2cc99126', 19, 1, 0)})
#
# 2025-09-02 10:04:03,715 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-c60ba13cf04eb4532036e60a1854fea7', 18.9, 1, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-c60ba13cf04eb4532036e60a1854fea7', 18.9, 1, 0)->('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 18.9, 1, 0))
# new run_spec: <Task ('getitem-c60ba13cf04eb4532036e60a1854fea7', 18.9, 1, 0) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 18.9, 1, 0)}
# new dependencies: frozenset({('rechunk-merge-fe497c6ff29d9da5ff745fbde117036f', 19, 1, 0)})
#
# 2025-09-02 10:04:03,716 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-40021c1abf1595b70860a6e0b8f15234', 18.9, 1, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-40021c1abf1595b70860a6e0b8f15234', 18.9, 1, 0)->('rechunk-merge-rechunk-split-getitem-40021c1abf1595b70860a6e0b8f15234', 18.9, 1, 0))
# new run_spec: <Task ('getitem-40021c1abf1595b70860a6e0b8f15234', 18.9, 1, 0) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-40021c1abf1595b70860a6e0b8f15234', 18.9, 1, 0)}
# new dependencies: frozenset({('rechunk-merge-e01feae861cd8f1643cd0bde2cc99126', 19, 1, 0)})
#
# 2025-09-02 10:04:10,347 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-c60ba13cf04eb4532036e60a1854fea7', 20.9, 2, 1) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-c60ba13cf04eb4532036e60a1854fea7', 20.9, 2, 1)->('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 20.9, 2, 1))
# new run_spec: <Task ('getitem-c60ba13cf04eb4532036e60a1854fea7', 20.9, 2, 1) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 20.9, 2, 1)}
# new dependencies: frozenset({('rechunk-merge-fe497c6ff29d9da5ff745fbde117036f', 21, 2, 1)})
#
# 2025-09-02 10:04:10,348 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-40021c1abf1595b70860a6e0b8f15234', 20.9, 2, 1) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-40021c1abf1595b70860a6e0b8f15234', 20.9, 2, 1)->('rechunk-merge-rechunk-split-getitem-40021c1abf1595b70860a6e0b8f15234', 20.9, 2, 1))
# new run_spec: <Task ('getitem-40021c1abf1595b70860a6e0b8f15234', 20.9, 2, 1) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-40021c1abf1595b70860a6e0b8f15234', 20.9, 2, 1)}
# new dependencies: frozenset({('rechunk-merge-e01feae861cd8f1643cd0bde2cc99126', 21, 2, 1)})
#
# 2025-09-02 10:04:15,431 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-c60ba13cf04eb4532036e60a1854fea7', 20.9, 2, 1) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-c60ba13cf04eb4532036e60a1854fea7', 20.9, 2, 1)->('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 20.9, 2, 1))
# new run_spec: <Task ('getitem-c60ba13cf04eb4532036e60a1854fea7', 20.9, 2, 1) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 20.9, 2, 1)}
# new dependencies: frozenset({('rechunk-merge-fe497c6ff29d9da5ff745fbde117036f', 21, 2, 1)})
#
# 2025-09-02 10:04:15,432 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-40021c1abf1595b70860a6e0b8f15234', 20.9, 2, 1) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-40021c1abf1595b70860a6e0b8f15234', 20.9, 2, 1)->('rechunk-merge-rechunk-split-getitem-40021c1abf1595b70860a6e0b8f15234', 20.9, 2, 1))
# new run_spec: <Task ('getitem-40021c1abf1595b70860a6e0b8f15234', 20.9, 2, 1) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-40021c1abf1595b70860a6e0b8f15234', 20.9, 2, 1)}
# new dependencies: frozenset({('rechunk-merge-e01feae861cd8f1643cd0bde2cc99126', 21, 2, 1)})
#
# 2025-09-02 10:04:20,778 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-40021c1abf1595b70860a6e0b8f15234', 24.9, 2, 2) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-40021c1abf1595b70860a6e0b8f15234', 24.9, 2, 2)->('rechunk-merge-rechunk-split-getitem-40021c1abf1595b70860a6e0b8f15234', 24.9, 2, 2))
# new run_spec: <Task ('getitem-40021c1abf1595b70860a6e0b8f15234', 24.9, 2, 2) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-40021c1abf1595b70860a6e0b8f15234', 24.9, 2, 2)}
# new dependencies: frozenset({('rechunk-merge-e01feae861cd8f1643cd0bde2cc99126', 25, 2, 2)})
#
# 2025-09-02 10:04:20,779 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-c60ba13cf04eb4532036e60a1854fea7', 24.9, 2, 2) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-c60ba13cf04eb4532036e60a1854fea7', 24.9, 2, 2)->('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 24.9, 2, 2))
# new run_spec: <Task ('getitem-c60ba13cf04eb4532036e60a1854fea7', 24.9, 2, 2) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 24.9, 2, 2)}
# new dependencies: frozenset({('rechunk-merge-fe497c6ff29d9da5ff745fbde117036f', 25, 2, 2)})
#
# 2025-09-02 10:04:26,685 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-c60ba13cf04eb4532036e60a1854fea7', 20.9, 2, 1) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-c60ba13cf04eb4532036e60a1854fea7', 20.9, 2, 1)->('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 20.9, 2, 1))
# new run_spec: <Task ('getitem-c60ba13cf04eb4532036e60a1854fea7', 20.9, 2, 1) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 20.9, 2, 1)}
# new dependencies: frozenset({('rechunk-merge-fe497c6ff29d9da5ff745fbde117036f', 21, 2, 1)})
#
# 2025-09-02 10:04:26,686 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-40021c1abf1595b70860a6e0b8f15234', 20.9, 2, 1) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-40021c1abf1595b70860a6e0b8f15234', 20.9, 2, 1)->('rechunk-merge-rechunk-split-getitem-40021c1abf1595b70860a6e0b8f15234', 20.9, 2, 1))
# new run_spec: <Task ('getitem-40021c1abf1595b70860a6e0b8f15234', 20.9, 2, 1) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-40021c1abf1595b70860a6e0b8f15234', 20.9, 2, 1)}
# new dependencies: frozenset({('rechunk-merge-e01feae861cd8f1643cd0bde2cc99126', 21, 2, 1)})
#
# 2025-09-02 10:04:33,243 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-40021c1abf1595b70860a6e0b8f15234', 23.9, 2, 2) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-40021c1abf1595b70860a6e0b8f15234', 23.9, 2, 2)->('rechunk-merge-rechunk-split-getitem-40021c1abf1595b70860a6e0b8f15234', 23.9, 2, 2))
# new run_spec: <Task ('getitem-40021c1abf1595b70860a6e0b8f15234', 23.9, 2, 2) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-40021c1abf1595b70860a6e0b8f15234', 23.9, 2, 2)}
# new dependencies: frozenset({('rechunk-merge-e01feae861cd8f1643cd0bde2cc99126', 24, 2, 2)})
#
# 2025-09-02 10:04:33,244 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-c60ba13cf04eb4532036e60a1854fea7', 23.9, 2, 2) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-c60ba13cf04eb4532036e60a1854fea7', 23.9, 2, 2)->('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 23.9, 2, 2))
# new run_spec: <Task ('getitem-c60ba13cf04eb4532036e60a1854fea7', 23.9, 2, 2) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 23.9, 2, 2)}
# new dependencies: frozenset({('rechunk-merge-fe497c6ff29d9da5ff745fbde117036f', 24, 2, 2)})
#
# 2025-09-02 10:04:40,161 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-40021c1abf1595b70860a6e0b8f15234', 24.9, 2, 2) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-40021c1abf1595b70860a6e0b8f15234', 24.9, 2, 2)->('rechunk-merge-rechunk-split-getitem-40021c1abf1595b70860a6e0b8f15234', 24.9, 2, 2))
# new run_spec: <Task ('getitem-40021c1abf1595b70860a6e0b8f15234', 24.9, 2, 2) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-40021c1abf1595b70860a6e0b8f15234', 24.9, 2, 2)}
# new dependencies: frozenset({('rechunk-merge-e01feae861cd8f1643cd0bde2cc99126', 25, 2, 2)})
#
# 2025-09-02 10:04:40,163 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-c60ba13cf04eb4532036e60a1854fea7', 24.9, 2, 2) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-c60ba13cf04eb4532036e60a1854fea7', 24.9, 2, 2)->('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 24.9, 2, 2))
# new run_spec: <Task ('getitem-c60ba13cf04eb4532036e60a1854fea7', 24.9, 2, 2) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 24.9, 2, 2)}
# new dependencies: frozenset({('rechunk-merge-fe497c6ff29d9da5ff745fbde117036f', 25, 2, 2)})
#
# 2025-09-02 10:04:46,305 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-40021c1abf1595b70860a6e0b8f15234', 24.9, 2, 2) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-40021c1abf1595b70860a6e0b8f15234', 24.9, 2, 2)->('rechunk-merge-rechunk-split-getitem-40021c1abf1595b70860a6e0b8f15234', 24.9, 2, 2))
# new run_spec: <Task ('getitem-40021c1abf1595b70860a6e0b8f15234', 24.9, 2, 2) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-40021c1abf1595b70860a6e0b8f15234', 24.9, 2, 2)}
# new dependencies: frozenset({('rechunk-merge-e01feae861cd8f1643cd0bde2cc99126', 25, 2, 2)})
#
# 2025-09-02 10:04:46,306 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-c60ba13cf04eb4532036e60a1854fea7', 24.9, 2, 2) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-c60ba13cf04eb4532036e60a1854fea7', 24.9, 2, 2)->('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 24.9, 2, 2))
# new run_spec: <Task ('getitem-c60ba13cf04eb4532036e60a1854fea7', 24.9, 2, 2) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 24.9, 2, 2)}
# new dependencies: frozenset({('rechunk-merge-fe497c6ff29d9da5ff745fbde117036f', 25, 2, 2)})
#
# 2025-09-02 10:04:53,589 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-c60ba13cf04eb4532036e60a1854fea7', 25.9, 2, 1) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-c60ba13cf04eb4532036e60a1854fea7', 25.9, 2, 1)->('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 25.9, 2, 1))
# new run_spec: <Task ('getitem-c60ba13cf04eb4532036e60a1854fea7', 25.9, 2, 1) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-c60ba13cf04eb4532036e60a1854fea7', 25.9, 2, 1)}
# new dependencies: frozenset({('rechunk-merge-fe497c6ff29d9da5ff745fbde117036f', 26, 2, 1)})
#
# ...
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-51428e1a9179d1fb4dc181f8db530fbb', 8.9, 0, 0)->('rechunk-merge-rechunk-split-getitem-51428e1a9179d1fb4dc181f8db530fbb', 8.9, 0, 0))
# new run_spec: <Task ('getitem-51428e1a9179d1fb4dc181f8db530fbb', 8.9, 0, 0) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-51428e1a9179d1fb4dc181f8db530fbb', 8.9, 0, 0)}
# new dependencies: frozenset({('rechunk-merge-87e05bb160620eba63e0969c21cbb431', 9, 0, 0)})
#
# 2025-09-02 13:31:15,375 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-51428e1a9179d1fb4dc181f8db530fbb', 23.9, 1, 2) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-51428e1a9179d1fb4dc181f8db530fbb', 23.9, 1, 2)->('rechunk-merge-rechunk-split-getitem-51428e1a9179d1fb4dc181f8db530fbb', 23.9, 1, 2))
# new run_spec: <Task ('getitem-51428e1a9179d1fb4dc181f8db530fbb', 23.9, 1, 2) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-51428e1a9179d1fb4dc181f8db530fbb', 23.9, 1, 2)}
# new dependencies: frozenset({('rechunk-merge-87e05bb160620eba63e0969c21cbb431', 24, 1, 2)})
#
# 2025-09-02 13:31:15,377 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-c377f929aa6ae5758033a5f93c630c98', 23.9, 1, 2) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-c377f929aa6ae5758033a5f93c630c98', 23.9, 1, 2)->('rechunk-merge-rechunk-split-getitem-c377f929aa6ae5758033a5f93c630c98', 23.9, 1, 2))
# new run_spec: <Task ('getitem-c377f929aa6ae5758033a5f93c630c98', 23.9, 1, 2) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-c377f929aa6ae5758033a5f93c630c98', 23.9, 1, 2)}
# new dependencies: frozenset({('rechunk-merge-06a7d46f862ab27b60159fe2716ae958', 24, 1, 2)})
#
# 2025-09-02 13:31:19,932 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-51428e1a9179d1fb4dc181f8db530fbb', 23.9, 1, 1) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-51428e1a9179d1fb4dc181f8db530fbb', 23.9, 1, 1)->('rechunk-merge-rechunk-split-getitem-51428e1a9179d1fb4dc181f8db530fbb', 23.9, 1, 1))
# new run_spec: <Task ('getitem-51428e1a9179d1fb4dc181f8db530fbb', 23.9, 1, 1) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-51428e1a9179d1fb4dc181f8db530fbb', 23.9, 1, 1)}
# new dependencies: frozenset({('rechunk-merge-87e05bb160620eba63e0969c21cbb431', 24, 1, 1)})
#
# 2025-09-02 13:31:19,936 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-c377f929aa6ae5758033a5f93c630c98', 23.9, 1, 1) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-c377f929aa6ae5758033a5f93c630c98', 23.9, 1, 1)->('rechunk-merge-rechunk-split-getitem-c377f929aa6ae5758033a5f93c630c98', 23.9, 1, 1))
# new run_spec: <Task ('getitem-c377f929aa6ae5758033a5f93c630c98', 23.9, 1, 1) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-c377f929aa6ae5758033a5f93c630c98', 23.9, 1, 1)}
# new dependencies: frozenset({('rechunk-merge-06a7d46f862ab27b60159fe2716ae958', 24, 1, 1)})
#
# 2025-09-02 13:31:55,776 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-c377f929aa6ae5758033a5f93c630c98', 11.9, 0, 2) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-c377f929aa6ae5758033a5f93c630c98', 11.9, 0, 2)->('rechunk-merge-rechunk-split-getitem-c377f929aa6ae5758033a5f93c630c98', 11.9, 0, 2))
# new run_spec: <Task ('getitem-c377f929aa6ae5758033a5f93c630c98', 11.9, 0, 2) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-c377f929aa6ae5758033a5f93c630c98', 11.9, 0, 2)}
# new dependencies: frozenset({('rechunk-merge-06a7d46f862ab27b60159fe2716ae958', 12, 0, 2)})
#
# 2025-09-02 13:31:55,778 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-51428e1a9179d1fb4dc181f8db530fbb', 11.9, 0, 2) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-51428e1a9179d1fb4dc181f8db530fbb', 11.9, 0, 2)->('rechunk-merge-rechunk-split-getitem-51428e1a9179d1fb4dc181f8db530fbb', 11.9, 0, 2))
# new run_spec: <Task ('getitem-51428e1a9179d1fb4dc181f8db530fbb', 11.9, 0, 2) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-51428e1a9179d1fb4dc181f8db530fbb', 11.9, 0, 2)}
# new dependencies: frozenset({('rechunk-merge-87e05bb160620eba63e0969c21cbb431', 12, 0, 2)})
#
# 2025-09-02 13:32:06,272 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-c377f929aa6ae5758033a5f93c630c98', 18.9, 2, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-c377f929aa6ae5758033a5f93c630c98', 18.9, 2, 0)->('rechunk-merge-rechunk-split-getitem-c377f929aa6ae5758033a5f93c630c98', 18.9, 2, 0))
# new run_spec: <Task ('getitem-c377f929aa6ae5758033a5f93c630c98', 18.9, 2, 0) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-c377f929aa6ae5758033a5f93c630c98', 18.9, 2, 0)}
# new dependencies: frozenset({('rechunk-merge-06a7d46f862ab27b60159fe2716ae958', 19, 2, 0)})
#
# 2025-09-02 13:32:06,273 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-51428e1a9179d1fb4dc181f8db530fbb', 18.9, 2, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-51428e1a9179d1fb4dc181f8db530fbb', 18.9, 2, 0)->('rechunk-merge-rechunk-split-getitem-51428e1a9179d1fb4dc181f8db530fbb', 18.9, 2, 0))
# new run_spec: <Task ('getitem-51428e1a9179d1fb4dc181f8db530fbb', 18.9, 2, 0) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-51428e1a9179d1fb4dc181f8db530fbb', 18.9, 2, 0)}
# new dependencies: frozenset({('rechunk-merge-87e05bb160620eba63e0969c21cbb431', 19, 2, 0)})
#
# 2025-09-02 13:32:10,900 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-51428e1a9179d1fb4dc181f8db530fbb', 21.9, 1, 1) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-51428e1a9179d1fb4dc181f8db530fbb', 21.9, 1, 1)->('rechunk-merge-rechunk-split-getitem-51428e1a9179d1fb4dc181f8db530fbb', 21.9, 1, 1))
# new run_spec: <Task ('getitem-51428e1a9179d1fb4dc181f8db530fbb', 21.9, 1, 1) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-51428e1a9179d1fb4dc181f8db530fbb', 21.9, 1, 1)}
# new dependencies: frozenset({('rechunk-merge-87e05bb160620eba63e0969c21cbb431', 22, 1, 1)})
#
# 2025-09-02 13:32:10,902 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-c377f929aa6ae5758033a5f93c630c98', 21.9, 1, 1) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-c377f929aa6ae5758033a5f93c630c98', 21.9, 1, 1)->('rechunk-merge-rechunk-split-getitem-c377f929aa6ae5758033a5f93c630c98', 21.9, 1, 1))
# new run_spec: <Task ('getitem-c377f929aa6ae5758033a5f93c630c98', 21.9, 1, 1) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-c377f929aa6ae5758033a5f93c630c98', 21.9, 1, 1)}
# new dependencies: frozenset({('rechunk-merge-06a7d46f862ab27b60159fe2716ae958', 22, 1, 1)})
#
# 2025-09-02 13:32:21,299 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-51428e1a9179d1fb4dc181f8db530fbb', 24, 2, 1) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-51428e1a9179d1fb4dc181f8db530fbb', 24, 2, 1)->('rechunk-merge-87e05bb160620eba63e0969c21cbb431', 24, 2, 1))
# new run_spec: Alias(('getitem-51428e1a9179d1fb4dc181f8db530fbb', 24, 2, 1)->('rechunk-merge-rechunk-split-getitem-51428e1a9179d1fb4dc181f8db530fbb', 24, 2, 1))
# old dependencies: {('rechunk-merge-87e05bb160620eba63e0969c21cbb431', 24, 2, 1)}
# new dependencies: frozenset({('rechunk-merge-rechunk-split-getitem-51428e1a9179d1fb4dc181f8db530fbb', 24, 2, 1)})
#
# 2025-09-02 13:32:21,300 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-c377f929aa6ae5758033a5f93c630c98', 24, 2, 1) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-c377f929aa6ae5758033a5f93c630c98', 24, 2, 1)->('rechunk-merge-06a7d46f862ab27b60159fe2716ae958', 24, 2, 1))
# new run_spec: Alias(('getitem-c377f929aa6ae5758033a5f93c630c98', 24, 2, 1)->('rechunk-merge-rechunk-split-getitem-c377f929aa6ae5758033a5f93c630c98', 24, 2, 1))
# old dependencies: {('rechunk-merge-06a7d46f862ab27b60159fe2716ae958', 24, 2, 1)}
# new dependencies: frozenset({('rechunk-merge-rechunk-split-getitem-c377f929aa6ae5758033a5f93c630c98', 24, 2, 1)})
#
# 2025-09-02 13:32:25,607 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-c377f929aa6ae5758033a5f93c630c98', 30.9, 0, 2) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-c377f929aa6ae5758033a5f93c630c98', 30.9, 0, 2)->('rechunk-merge-rechunk-split-getitem-c377f929aa6ae5758033a5f93c630c98', 30.9, 0, 2))
# new run_spec: <Task ('getitem-c377f929aa6ae5758033a5f93c630c98', 30.9, 0, 2) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-c377f929aa6ae5758033a5f93c630c98', 30.9, 0, 2)}
# new dependencies: frozenset({('rechunk-merge-06a7d46f862ab27b60159fe2716ae958', 31, 0, 2)})
#
# 2025-09-02 13:32:25,608 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-51428e1a9179d1fb4dc181f8db530fbb', 30.9, 0, 2) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-51428e1a9179d1fb4dc181f8db530fbb', 30.9, 0, 2)->('rechunk-merge-rechunk-split-getitem-51428e1a9179d1fb4dc181f8db530fbb', 30.9, 0, 2))
# new run_spec: <Task ('getitem-51428e1a9179d1fb4dc181f8db530fbb', 30.9, 0, 2) getitem(...)>
# old dependencies: {('rechunk-merge-rechunk-split-getitem-51428e1a9179d1fb4dc181f8db530fbb', 30.9, 0, 2)}
# new dependencies: frozenset({('rechunk-merge-87e05bb160620eba63e0969c21cbb431', 31, 0, 2)})
#
# 2025-09-02 13:32:36,039 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-c64183eba18c6a2e766d879126a76afe', 3, 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-c64183eba18c6a2e766d879126a76afe', 3, 0, 0)->('masked_where-getitem-c64183eba18c6a2e766d879126a76afe', 3, 0, 0))
# new run_spec: <Task ('getitem-c64183eba18c6a2e766d879126a76afe', 3, 0, 0) getitem(...)>
# old dependencies: {('masked_where-getitem-c64183eba18c6a2e766d879126a76afe', 3, 0, 0)}
# new dependencies: frozenset({('getitem-15a339abb7ca27719b71b990c7a459ca', 3, 0, 0)})

# %% [markdown]
# ## Datasets

# %%
from esmvalcore.dataset import Dataset
# Out:
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/esmvalcore/config/_config_object.py:639: ESMValCoreDeprecationWarning: Usage of the single configuration file ~/.esmvaltool/config-user.yml or specifying it via CLI argument `--config_file` has been deprecated in ESMValCore version 2.12.0 and is scheduled for removal in version 2.14.0. Please run `mkdir -p ~/.config/esmvaltool && mv /home/548/cxc548/.esmvaltool/config-user.yml ~/.config/esmvaltool` (or alternatively use a custom `--config_dir`) and omit `--config_file`.
#   config_obj.reload()
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/esmvalcore/config/_config_validators.py:405: ESMValCoreDeprecationWarning: The configuration option or command line argument `config_file` has been deprecated in ESMValCore version 2.12.0 and is scheduled for removal in version 2.14.0. Please use the option `config_dir` instead.
#   _handle_deprecation(option, deprecated_version, remove_version, more_info)
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/webob/compat.py:5: DeprecationWarning: 'cgi' is deprecated and slated for removal in Python 3.13
#   from cgi import parse_header
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/esmpy/__init__.py:106: DeprecationWarning: Implicit None on return values is deprecated and will raise KeyErrors.
#   __author__ = msg["Author"]

# %%
model_ctrldatasets = {
"ACCESS-ESM1-5": 
    Dataset(
    short_name='ts',
    project='CMIP6',
    mip="Amon",
    exp="piControl",
    ensemble="r1i1p1f1",
    timerange="0900101/11000101",
    dataset="ACCESS-ESM1-5",
    grid="gn"
),
## Note: It is possible to use tos (sea_surface_temperature; degC; ocean; mon) 
# "ACCESS-ESM1-5": 
#     Dataset(
#     short_name='tos',
#     project='CMIP6',
#     mip="Omon",
#     exp="historical",
#     ensemble="r1i1p1f1",
#     timerange="18500101/20190101",
#     dataset="ACCESS-ESM1-5",
#     grid="gn"
# )
}

obs_datasets = {
"HadISST": 
    Dataset(
    short_name='ts',
    dataset='HadISST',
    mip="Amon",
    project='OBS',
    timerange="19790101/20190101",
    type='reanaly',
    tier=2),
# "TROPFLUX":
#     Dataset(
#     short_name='tos',
#     dataset='TROPFLUX',
#     mip="Omon",
#     project='OBS6',
#     type='reanaly',
#     tier=2),
}

# %% [markdown]
# ## Add Ancillary files

# %%
for name, dataset in model_ctrldatasets.items():
    dataset.add_supplementary(short_name='sftlf', mip="fx")
    dataset.add_supplementary(short_name="areacella", mip="fx")

# %%
model_ctrldatasets = {name: dataset.load() for name, ctrldataset in model_ctrldatasets.items()}
obs_datasets = {name: dataset.load() for name, dataset in obs_datasets.items()}

import iris
from iris.util import equalise_attributes

#filename  = "/scratch/p66/yz9299/MOPPeR_outputs/CMIP6/CMIP/CSIRO/ACCESS-ESM1-6/piControl-spinup/r1i1p1f1/Amon/ts/gn/v20250801/*nc"
filename = "/scratch/p66/fc6164/MOPPeR/ts_Amon_ACCESS-ESM1-5_piControl_r1i1p1f1_gn_159201-209112.nc"

esm16cube = iris.load_cube(filename,'surface_temperature')
# Out:
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/esmvalcore/config/_config_validators.py:405: ESMValCoreDeprecationWarning: The configuration option or command line argument `config_file` has been deprecated in ESMValCore version 2.12.0 and is scheduled for removal in version 2.14.0. Please use the option `config_dir` instead.
#   _handle_deprecation(option, deprecated_version, remove_version, more_info)
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/esmvalcore/config/_config_validators.py:405: ESMValCoreDeprecationWarning: The configuration option or command line argument `config_file` has been deprecated in ESMValCore version 2.12.0 and is scheduled for removal in version 2.14.0. Please use the option `config_dir` instead.
#   _handle_deprecation(option, deprecated_version, remove_version, more_info)
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/esmvalcore/config/_config_validators.py:405: ESMValCoreDeprecationWarning: The configuration option or command line argument `config_file` has been deprecated in ESMValCore version 2.12.0 and is scheduled for removal in version 2.14.0. Please use the option `config_dir` instead.
#   _handle_deprecation(option, deprecated_version, remove_version, more_info)
# WARNING:esmvalcore.local:Configured 'CMIP6' rootpaths '/g/data/zv30/cmip/CMIP6, /g/data/nf33/public/data/APP4/CMIP6' do not exist
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/esmvalcore/preprocessor/_io.py:293: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   calendar_index = int(
# WARNING:esmvalcore.cmor._fixes.fix.genericfix:Long name changed from 'Percentage of the grid  cell occupied by land (including lakes)' to 'Percentage of the Grid Cell Occupied by Land (Including Lakes)'
# (for file /g/data/fs38/publications/CMIP6/CMIP/CSIRO/ACCESS-ESM1-5/piControl/r1i1p1f1/fx/sftlf/gn/v20210316/sftlf_fx_ACCESS-ESM1-5_piControl_r1i1p1f1_gn.nc)
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/esmvalcore/config/_config_validators.py:405: ESMValCoreDeprecationWarning: The configuration option or command line argument `config_file` has been deprecated in ESMValCore version 2.12.0 and is scheduled for removal in version 2.14.0. Please use the option `config_dir` instead.
#   _handle_deprecation(option, deprecated_version, remove_version, more_info)
# WARNING:esmvalcore.local:Configured 'OBS' rootpaths '/g/data/kj13/datasets/esmvaltool/obsdata-v2' do not exist
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/iris/fileformats/cf.py:664: IrisCfMissingVarWarning: Missing CF-netCDF grid mapping variable 'latitude_longitude', referenced by netCDF variable 'ts'
#   warnings.warn(
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/iris/fileformats/cf.py:880: IrisCfMissingVarWarning: Missing CF-netCDF measure variable 'areacella', referenced by netCDF variable 'ts'
#   warnings.warn(

# %%
from esmvalcore.preprocessor import anomalies
from esmvalcore.preprocessor import area_statistics
from esmvalcore.preprocessor import rolling_window_statistics
from esmvalcore.preprocessor import meridional_statistics
from esmvalcore.preprocessor import convert_units
from esmvalcore.preprocessor import extract_region
from esmvalcore.preprocessor import extract_time
from esmvalcore.preprocessor import extract_month
from esmvalcore.preprocessor import regrid
from esmvalcore.preprocessor import detrend
from esmvalcore.preprocessor import mask_landsea
import iris

import matplotlib.pyplot as plt
import iris.quickplot as qplt
import numpy as np
import xarray as xr
from datetime import datetime

# %%
def sst_enso_n34(cube,start,end):
    nino34_latext_region = {"start_longitude": 190., "end_longitude": 240., "start_latitude": -5., "end_latitude": 5.}
    cube = extract_time(cube, start_year=start, start_month=1, start_day=1, end_year=end, end_month=12, end_day=31)    
    cube = convert_units(cube, units="degC")
    cube = regrid(cube, target_grid="1x1", scheme="linear")
    cube = mask_landsea(cube, mask_out="land")
    cube = extract_region(cube, **nino34_latext_region)
    # remove time mean
    cube = anomalies(cube, period='monthly') 
    cube = rolling_window_statistics(cube, coordinate='time', operator='mean', window_length=5)##rolling window cuts off months?
    # cube = rolling_window_statistics(cube, coordinate='time', operator='mean', window_length=5) #smooth once
    cube = area_statistics(cube,operator='mean')

    return cube

def sst_meridional(cube,start,end): ##along latitude for area
    nino34_latext_region = {"start_longitude": 160., "end_longitude": 280., "start_latitude": -5., "end_latitude": 5.}
    cube = convert_units(cube, units="degC")
    cube = extract_time(cube, start_year=start, start_month=1, start_day=1, end_year=end, end_month=12, end_day=31)    
    cube = regrid(cube, target_grid="1x1", scheme="linear")
    cube = mask_landsea(cube, mask_out="land")
    cube = anomalies(cube, period='monthly')
    cube = extract_region(cube, **nino34_latext_region)
    cube = rolling_window_statistics(cube, coordinate='time', operator='mean', window_length=5)
    # cube = rolling_window_statistics(cube, coordinate='time', operator='mean', window_length=5)
    cube = meridional_statistics(cube,operator='mean')
    return cube

#rmse

# %%
model_ctrldatasets_prep1 = {name: sst_enso_n34(dataset,900,1100) for name, dataset in model_ctrldatasets.items()}
model_ctrldatasets_prep2 = {name: sst_meridional(dataset,900,1100) for name, dataset in model_ctrldatasets.items()}

model_datasets_prep1 = sst_enso_n34(esm16cube,1800,2000)
model_datasets_prep2 = sst_meridional(esm16cube,1800,2000)

obs_datasets_prep1 = {name: sst_enso_n34(dataset,1900,2014) for name, dataset in obs_datasets.items()}
obs_datasets_prep2 = {name: sst_meridional(dataset,1900,2014) for name, dataset in obs_datasets.items()}
# Out:
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/iris/cube.py:4896: IrisIgnoringBoundsWarning: The bounds of coordinate 'time' were ignored in the rolling window operation.
#   warnings.warn(
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/iris/cube.py:4896: IrisIgnoringBoundsWarning: The bounds of coordinate 'time' were ignored in the rolling window operation.
#   warnings.warn(
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/iris/cube.py:4341: IrisUserWarning: Collapsing spatial coordinate 'latitude' without weighting
#   warnings.warn(
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/iris/cube.py:4896: IrisIgnoringBoundsWarning: The bounds of coordinate 'time' were ignored in the rolling window operation.
#   warnings.warn(
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/iris/cube.py:4896: IrisIgnoringBoundsWarning: The bounds of coordinate 'time' were ignored in the rolling window operation.
#   warnings.warn(
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/iris/cube.py:4341: IrisUserWarning: Collapsing spatial coordinate 'latitude' without weighting
#   warnings.warn(
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/iris/cube.py:4896: IrisIgnoringBoundsWarning: The bounds of coordinate 'time' were ignored in the rolling window operation.
#   warnings.warn(
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/iris/cube.py:4896: IrisIgnoringBoundsWarning: The bounds of coordinate 'time' were ignored in the rolling window operation.
#   warnings.warn(
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/iris/cube.py:4341: IrisUserWarning: Collapsing spatial coordinate 'latitude' without weighting
#   warnings.warn(

# %% [markdown]
# ## Diagnostic Level 1
#
# The first level shows the diagnostic used to compute the metric and highlight the main differences between the model and the reference.

# %%
def sst_regressed(n34_cube): 
    """Regression function for sst_time_series on sst_enso."""
    n34_dec = extract_month(n34_cube, 12)
    leadlagyr = 3
    n34_dec_years = [n34_dec.coord('time').units.num2date(time).year
                     for time in n34_dec.coord('time').points]
    event_years = n34_dec_years[leadlagyr:-leadlagyr]
    # Ensure that the selected years are not the last years
    years_of_interest = []
    for yr in event_years:
        years_of_interest.append([yr - 2, yr - 1, yr, yr + 1, yr + 2, yr + 3])

    n34_selected = []
    print(len(years_of_interest))
    for enso_epoch in years_of_interest:
        # Select the data for the current year and append it to n34_selected
        year_enso = iris.Constraint(time=lambda cell: cell.point.year in enso_epoch)
        cube_2 = n34_cube.extract(year_enso)
        n34_selected.append(cube_2.core_data()) 
        
    event_constr = iris.Constraint(time=lambda cell: cell.point.year in event_years)
    n34_dec_ct = n34_dec.extract(event_constr)
    
    # 1) linear regression of sst_time_series on sst_enso
    a_data = np.array(n34_selected) #write for dask?
    b_data = n34_dec_ct.data
    b_with_intercept = np.vstack([b_data, np.ones_like(b_data)]).T
    print(a_data.shape, b_with_intercept.shape)
    coefs, _, _, _ = np.linalg.lstsq(b_with_intercept, a_data, rcond=None)
    
    return coefs[0]

# %%
model_ctrln34 = model_ctrldatasets_prep1["ACCESS-ESM1-5"]
model_ctrln34_area = model_ctrldatasets_prep2["ACCESS-ESM1-5"]

model_n34 = model_datasets_prep1#["ACCESS-CM2"]
model_n34_area = model_datasets_prep2#["ACCESS-CM2"]

obs_n34 = obs_datasets_prep1["HadISST"]
obs_n34_area = obs_datasets_prep2["HadISST"]

# %%
print(datetime.now())
## metric computation - rmse of slopes

ctrlmodel = sst_regressed(model_ctrln34)
model = sst_regressed(model_n34)

print(datetime.now())

obs = sst_regressed(obs_n34)
print(datetime.now())

rmse = np.sqrt(np.mean((obs - model) ** 2))
rmse
# Out:
# 2025-09-02 10:01:52.172447
# 193
# (193, 72) (193, 2)
# 194
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/iris/fileformats/netcdf/_thread_safe_nc.py:340: UserWarning: WARNING: missing_value not used since it
# cannot be safely cast to variable data type
#   var = variable[keys]
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/iris/fileformats/netcdf/_thread_safe_nc.py:340: UserWarning: WARNING: missing_value not used since it
# cannot be safely cast to variable data type
#   var = variable[keys]
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/iris/fileformats/netcdf/_thread_safe_nc.py:340: UserWarning: WARNING: missing_value not used since it
# cannot be safely cast to variable data type
#   var = variable[keys]
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/iris/fileformats/netcdf/_thread_safe_nc.py:340: UserWarning: WARNING: missing_value not used since it
# cannot be safely cast to variable data type
#   var = variable[keys]
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/iris/fileformats/netcdf/_thread_safe_nc.py:340: UserWarning: WARNING: missing_value not used since it
# cannot be safely cast to variable data type
#   var = variable[keys]
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/iris/fileformats/netcdf/_thread_safe_nc.py:340: UserWarning: WARNING: missing_value not used since it
# cannot be safely cast to variable data type
#   var = variable[keys]
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/iris/fileformats/netcdf/_thread_safe_nc.py:340: UserWarning: WARNING: missing_value not used since it
# cannot be safely cast to variable data type
#   var = variable[keys]
# (194, 72) (194, 2)
# 2025-09-02 11:08:05.043281
# 29
# (29, 72) (29, 2)
# 2025-09-02 11:09:26.562180
# 0.09839954

# %%
months = np.arange(1, 73) - 36

# Plot the slope
plt.plot(months, obs, label='HadISST', lw=4,color='black')
plt.plot(months, ctrlmodel, label='ESM1.6 piControl', lw=4,linestyle='--',color='blue')
plt.plot(months, model, label='JuneSpinUp', lw=4,color='blue')

# Draw a black dashed line at y=0.25
# plt.axhline(y=0.25, color='black', linestyle='--', label='0.25 threshold')

# Draw a thicker line at y=0
plt.axhline(y=0, color='black', linewidth=2) #, label='Zero Line')

# Define custom ticks for the x-axis (every 6 months)
xticks = np.arange(1, 73, 6) - 36  # Adjust for lead/lag months
xtick_labels = ['Jan', 'Jul'] * (len(xticks) // 2)

# Set the labels and titles
plt.xlabel('Lead & Lag Months')
plt.ylabel('Degree C / C')
plt.legend()
plt.grid(linestyle='--')

# Apply the custom ticks and labels to the x-axis
plt.xticks(xticks, xtick_labels)
plt.yticks(np.arange(-2,2.5, step=1))

# Adding RMSE text on top of the plot
plt.text(0.5, 0.95, f'RMSE: {rmse:.2f} °C/°C', fontsize=12, ha='center', transform=plt.gca().transAxes,
         bbox=dict(facecolor='white', alpha=0.8, edgecolor='none'))
# Show the plot
plt.show()

# %% [markdown]
# Figure 1: Temporal evolution of sea surface temperature anomalies (SSTA) in the central equatorial Pacific (Niño 3.4 region average), illustrating the ENSO-associated variability. The model tends to exhibit overly frequent transitions between negative and positive SSTA phases. The black curve represents the reference data, while the blue curve corresponds to the model output. The derived metric is the temporal root mean square error (RMSE) between the model and reference curves.

# %% [markdown]
# # Diagnostic Level 2
#
# The second level shows the broader picture to better understand the spatial-temporal pattern of ENSO: the Hovmöller of the anomalies in the equatorial Pacific.

# %%
def dec_and_years(n34_cube):

    n34_dec = extract_month(n34_cube, 12)
    leadlagyr = 3
    n34_dec_years = [n34_dec.coord('time').units.num2date(time).year
                     for time in n34_dec.coord('time').points]
    event_years = n34_dec_years[leadlagyr:-leadlagyr]
    # Ensure that the selected years are not the last years
    return n34_dec, event_years

def sst_regressed_2d(event_years, n34_area, n34_dec):
    """Regression function for sst_time_series area on sst_enso."""
    n34_area_selected = []    
    for yr in event_years:
        enso_epoch = [yr - 2, yr - 1, yr, yr + 1, yr + 2, yr + 3]
        year_enso = iris.Constraint(time=lambda cell: cell.point.year in enso_epoch)

        n34_area_selected.append(n34_area.extract(year_enso).data)
        
    event_constr = iris.Constraint(time=lambda cell: cell.point.year in event_years)
    n34_dec_ct = n34_dec.extract(event_constr)
    print(f'{len(event_years)} years, cube meri:{n34_area.shape}')
    
    #2 area linear regression
    b_data = n34_dec_ct.data
    b_with_intercept = np.vstack([b_data, np.ones_like(b_data)]).T
    a_arr = np.array(n34_area_selected)
    a_data = a_arr.reshape(a_arr.shape[0], -1)
    
    print(a_arr.shape, a_data.shape, b_data.shape)
    coefs_area, _, _, _ = np.linalg.lstsq(b_with_intercept, a_data, rcond=None)
    slope_area = coefs_area[0].reshape(a_arr.shape[1], a_arr.shape[2])
    
    return slope_area

# %%
print(datetime.now())

ctrlmod_dec, ctrlmod_years = dec_and_years(model_ctrln34)
ctrlmodel_area = sst_regressed_2d(ctrlmod_years, model_ctrln34_area, ctrlmod_dec)

mod_dec, mod_years = dec_and_years(model_n34)
model_area = sst_regressed_2d(mod_years, model_n34_area, mod_dec)

print(model_area.shape, datetime.now())

obs_dec, obs_years = dec_and_years(obs_n34)
obs_area = sst_regressed_2d(obs_years, obs_n34_area, obs_dec)
print(obs_area.shape,datetime.now())
# Out:
# 2025-09-02 11:09:26.932586
# 193 years, cube meri:(2393, 120)
# (193, 72, 120) (193, 8640) (193,)
# 194 years, cube meri:(120, 2408)
# (194, 120, 72) (194, 8640) (194,)
# (120, 72) 2025-09-02 12:30:36.165539
# 29 years, cube meri:(428, 120)
# (29, 72, 120) (29, 8640) (29,)
# (72, 120) 2025-09-02 12:32:32.133719

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define custom ticks for the y-axis (every 6 months)
yticks = range(1, 73, 6)
ytick_labels = ['Jan', 'Jul'] * (len(yticks) // 2)

# Define shared color limits and colorbar ticks
vmin = -1.2
vmax = 1.2
ticks = np.arange(vmin, vmax + 0.2, 0.2)  # Ticks from -1.2 to 1.2 at intervals of 0.2

# Create the subplots
fig, (ax1, ax2,ax3) = plt.subplots(1, 3, figsize=(9, 12), sharey=True)

# First subplot: HadISST
c1 = ax1.contourf(
    obs_n34_area.coord('longitude').points,
    range(1, 73),
    obs_area, #area
    levels=np.linspace(vmin, vmax, 14),
    cmap='RdBu_r',
    extend='both'  # Allow for values beyond vmin and vmax
)
ax1.set_ylabel('Months')
ax1.set_xlabel('Longitude')
ax1.set_xlim([160, 280])
ax1.set_title('HadISST')#: reg(ENSO SSTA, SSTA)')
ax1.set_yticks(yticks)
ax1.set_yticklabels(ytick_labels)

# Second subplot: picontrol
c3 = ax2.contourf(
    model_ctrln34_area.coord('longitude').points,
    range(1, 73),
    ctrlmodel_area,
    levels=np.linspace(vmin, vmax, 14),
    cmap='RdBu_r',
    extend='both'  # Allow for values beyond vmin and vmax
)
ax2.set_xlabel('Longitude')
ax2.set_title('ESM1.5 piControl')#: reg(ENSO SSTA, SSTA)')
ax2.set_xlim([160, 280])

# third subplot: Model
c3 = ax3.contourf(
    model_n34_area.coord('longitude').points,
    range(1, 73),
    model_area.T,
    levels=np.linspace(vmin, vmax, 14),
    cmap='RdBu_r',
    extend='both'  # Allow for values beyond vmin and vmax
)
ax3.set_xlabel('Longitude')
ax3.set_title('JuneSpinUp')#: reg(ENSO SSTA, SSTA)')
ax3.set_xlim([160, 280])

# Adjust the layout to add space for the colorbar
fig.subplots_adjust(bottom=0.15, right=1.0)  # Adjust bottom margin to fit colorbar

# Add a horizontal colorbar beneath the subplots
cbar = fig.colorbar(c1, ax=[ax1, ax2,ax3], label='Regression (°C / °C)', orientation='horizontal', ticks=ticks, fraction=0.05, pad=0.08)

# Display the plot
plt.show()

# %% [markdown]
# Figure 2: spatial-temporal structure of sea surface temperature anomalies (SSTA) associated with ENSO in the equatorial Pacific (5°S-5°N average), showing usually the too frequent swing from negative to positive SSTA, along with maximum anomalies during ENSO peak lasting too long. The left and right Hovmöllers show respectively the reference and the model.

# %% [markdown]
# ## Diagnostic level 3

# %%
from esmvalcore.preprocessor import (
                        mask_above_threshold, mask_below_threshold,
)
import numpy as np

def mask_to_years(events):
    maskedTime = np.ma.masked_array(events.coord('time').points, mask=events.data.mask)
    return [events.coord('time').units.num2date(time).year for time in maskedTime.compressed()]
    
def enso_events(cube): # get cube years min/max, remove 3:-3
    datayears = [cube.coord('time').units.num2date(time).year for time in cube.coord('time').points]
    leadlagyrs = datayears[:3] + datayears[-3:]
    
    cb_std = cube.data.std()
    a_events = mask_to_years(mask_above_threshold(cube.copy(), -0.5*cb_std))
    o_events = mask_to_years(mask_below_threshold(cube.copy(), 0.5*cb_std))
    events = {'la nina':a_events, 'el nino':o_events} 
    for key,yrls in events.items():
        events[key] = [yr for yr in yrls if yr not in leadlagyrs]
        
    return events #dec year

# %%
months = np.arange(1, 73) - 36

def enso_composite_plot(model_n34, label, line):
    n34_dec = extract_month(model_n34, 12)
    events = enso_events(n34_dec) #check years not in first/last 3
    colors = {'la nina':'blue', 'el nino':'red'}
    print(events)
    for enso, years in events.items(): 
        year_contraint = iris.Constraint(time=lambda cell: cell.point.year in years)
        model_cb = n34_dec.extract(year_contraint) #values for regression
        
        cube_data=[]
        for yr in years:
            enso_epoch = [yr - 2, yr - 1, yr, yr + 1, yr + 2, yr + 3]
            year_enso = iris.Constraint(time=lambda cell: cell.point.year in enso_epoch)
            cube_2 = model_n34.extract(year_enso) #extract rolling 6yr
            cube_data.append(cube_2.data.data)
        
        # No regression, mean enso epoch
        arr = np.array(cube_data)
        mean = np.mean(arr, axis=0)
  #      print(model_cb.shape, model_n34.shape, "array shape:", arr.shape, len(cube_data), len(cube_data[0]))

        plt.plot(months, mean, label=f'{enso} {label}', linestyle=line, color=colors[enso], lw=3)

    return cube_data

#plot model and obs
enso_composite_plot(obs_n34, 'Ref HadISST', 'dashdot')

enso_composite_plot(model_ctrln34, 'ESM1.5 piControl', 'dashed')

enso_composite_plot(model_n34, 'JuneSpinUp', 'solid')

plt.axhline(y=0, color='black', linewidth=2)

xticks = np.arange(1, 73, 6) - 36  # Adjust for lead/lag months
xtick_labels = ['Jan', 'Jul'] * (len(xticks) // 2)
plt.xticks(xticks, xtick_labels)
plt.xlim(-35,36)
plt.grid(linestyle='--')
plt.yticks(np.arange(-2,2.5, step=1))
plt.legend()
plt.show()
# Out:
# {'la nina': [1983, 1984, 1985, 1988, 1995, 1998, 1999, 2000, 2005, 2007, 2008, 2010], 'el nino': [1982, 1986, 1987, 1991, 1994, 1997, 2002, 2004, 2006, 2009]}
# {'la nina': [903, 905, 913, 917, 919, 921, 926, 928, 929, 940, 943, 945, 947, 950, 953, 959, 963, 966, 969, 970, 971, 974, 979, 982, 984, 989, 990, 992, 995, 998, 1000, 1004, 1005, 1010, 1011, 1014, 1015, 1020, 1022, 1029, 1035, 1038, 1039, 1042, 1047, 1052, 1056, 1059, 1061, 1063, 1065, 1068, 1071, 1073, 1075, 1078, 1086, 1090, 1093], 'el nino': [906, 907, 909, 910, 912, 914, 915, 918, 922, 923, 925, 927, 932, 934, 936, 939, 941, 942, 949, 951, 952, 955, 958, 960, 968, 972, 973, 976, 981, 983, 985, 986, 994, 997, 1002, 1006, 1008, 1009, 1012, 1013, 1018, 1019, 1021, 1028, 1031, 1036, 1037, 1040, 1041, 1043, 1046, 1053, 1055, 1058, 1066, 1067, 1070, 1074, 1076, 1079, 1080, 1085, 1087, 1092, 1094]}
# {'la nina': [1803, 1807, 1811, 1817, 1820, 1822, 1824, 1827, 1835, 1836, 1838, 1841, 1842, 1843, 1844, 1848, 1851, 1861, 1863, 1867, 1868, 1871, 1873, 1874, 1878, 1880, 1883, 1889, 1893, 1894, 1901, 1903, 1905, 1908, 1913, 1914, 1916, 1920, 1921, 1924, 1930, 1936, 1940, 1943, 1946, 1953, 1956, 1957, 1964, 1965, 1971, 1976, 1977, 1978, 1985, 1987, 1988, 1990, 1992, 1993, 1995, 1996], 'el nino': [1804, 1810, 1813, 1818, 1819, 1823, 1828, 1832, 1833, 1834, 1837, 1840, 1846, 1850, 1853, 1855, 1858, 1862, 1866, 1869, 1870, 1872, 1875, 1877, 1882, 1885, 1887, 1890, 1897, 1898, 1900, 1904, 1907, 1912, 1915, 1918, 1919, 1926, 1928, 1931, 1932, 1938, 1941, 1942, 1944, 1945, 1949, 1958, 1963, 1967, 1968, 1970, 1972, 1975, 1979, 1980, 1986, 1989, 1991, 1994]}

# %% [markdown]
# **Figure 3**: temporal structure of sea surface temperature anomalies (SSTA) during La Niña and El Niño in the central equatorial Pacific (Niño3.4 averaged), showing usually the model's tendency to swing from El Niño to La Niña and the weak (of not frequent enough) capacity of the models to generate two-years La Niña. The blue and red curves show respectively La Niña composite and the El Niño composite, dashed and solid lines show respectively the reference and the model.

# %% [markdown]
# ## Diagnostic level 4

# %%
def sst_2d(event_years, n34_area):
    n34_area_selected = []    
    for yr in event_years:
        enso_epoch = [yr - 2, yr - 1, yr, yr + 1, yr + 2, yr + 3]
        year_enso = iris.Constraint(time=lambda cell: cell.point.year in enso_epoch)
        n34_area_selected.append(n34_area.extract(year_enso).data)

    print(f'{len(event_years)} years, cube meri:{n34_area.shape}')
    arr = np.array(n34_area_selected)
    a_data = arr.reshape(arr.shape[0], -1)
    means = np.mean(a_data, axis=0)
    return means.reshape(arr.shape[1], arr.shape[2])
    
def enso_composite_plot4(n34_cube, n34_area, label, i, axes):
    n34_dec = extract_month(n34_cube, 12)
    events = enso_events(n34_dec)

    for enso, years in events.items():
        # plot area
        means = sst_2d(years, n34_area)
        cplot = plot_ssta(axes[enso], n34_area.coord('longitude'), means, f'{enso} {label}', i)
        
    return cplot 

# subplot each regression data
def plot_ssta(ax, area_coordlon, ssta, label, i):
    vmin = -1.2
    vmax = 1.2
    c1 = ax[i].contourf(
        area_coordlon.points,
        range(1, 73),
        ssta,
        levels=np.linspace(vmin, vmax, 14),
        cmap='RdBu_r',
        extend='both'  # Allow for values beyond vmin and vmax
    )
    ax[i].set_ylabel('Months')
    ax[i].set_xlabel('Longitude')
    ax[i].set_xlim([160,280])
    ax[i].set_title(f'{label}: reg SSTA')
    ax[i].set_yticks(range(1, 73, 6))
    ax[i].set_yticklabels(['Jan', 'Jul'] * (len(yticks) // 2))
    return c1

# %%
# Create the subplots
fig, (ax1, ax2) = plt.subplots(2, 2,figsize=(9, 20), sharey=True)
# # layout rows la nina ax1, el nino ax2 for datasets 0,1
axes_rows = {'la nina':ax1, 'el nino':ax2}

# obs
c1 = enso_composite_plot4(obs_n34, obs_n34_area, 'Obs', 0, axes_rows)
        
c1 = enso_composite_plot4(model_ctrln34, model_ctrln34_area, 'ESM1-5 piControl', 1, axes_rows) 

c1 = enso_composite_plot4(model_n34, model_n34_area, 'JuneSpinUp', 2, axes_rows) 

# Adjust the layout to add more space for the colorbar on the right
plt.subplots_adjust(right=1.05)

cbar = fig.colorbar(c1, ax=[ax2[0], ax2[1],ax2[2]], label='ENSO SSTA °C', orientation='horizontal', 
                    ticks=np.arange(vmin, vmax + 0.2, 0.2), fraction=0.05, pad=0.08)
# Out:
# 12 years, cube meri:(428, 120)
# 10 years, cube meri:(428, 120)
# 59 years, cube meri:(2393, 120)
# 65 years, cube meri:(2393, 120)
# 62 years, cube meri:(120, 2408)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[19], line 11
#       7 c1 = enso_composite_plot4(obs_n34, obs_n34_area, 'Obs', 0, axes_rows)
#       9 c1 = enso_composite_plot4(model_ctrln34, model_ctrln34_area, 'ESM1-5 piControl', 1, axes_rows)
# ---> 11 c1 = enso_composite_plot4(model_n34, model_n34_area, 'JuneSpinUp', 2, axes_rows)
#      13 # Adjust the layout to add more space for the colorbar on the right
#      14 plt.subplots_adjust(right=1.05)
#
# Cell In[18], line 21, in enso_composite_plot4(n34_cube, n34_area, label, i, axes)
#      18 for enso, years in events.items():
#      19     # plot area
#      20     means = sst_2d(years, n34_area)
# ---> 21     cplot = plot_ssta(axes[enso], n34_area.coord('longitude'), means, f'{enso} {label}', i)
#      23 return cplot
#
# Cell In[18], line 29, in plot_ssta(ax, area_coordlon, ssta, label, i)
#      27 vmin = -1.2
#      28 vmax = 1.2
# ---> 29 c1 = ax[i].contourf(
#      30     area_coordlon.points,
#      31     range(1, 73),
#      32     ssta,
#      33     levels=np.linspace(vmin, vmax, 14),
#      34     cmap='RdBu_r',
#      35     extend='both'  # Allow for values beyond vmin and vmax
#      36 )
#      37 ax[i].set_ylabel('Months')
#      38 ax[i].set_xlabel('Longitude')
#
# IndexError: index 2 is out of bounds for axis 0 with size 2

# %% [markdown]
# Figure 4: spatial-temporal structure of sea surface temperature anomalies (SSTA) during La Niña and El Niño in the equatorial Pacific (5°S-5°N average), showing usually the model's tendency to swing from El Niño to La Niña and the weak (of not frequent enough) capacity of the models to generate two-years La Niña. The left and right Hovmöllers show respectively the reference and the model. The first and second rows show respectively the La Niña composites and the El Niño composites.
