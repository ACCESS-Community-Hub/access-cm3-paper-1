# %%
import warnings
import os
warnings.simplefilter(action='ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
#parameters

### USER EDIT start
esm_file='/g/data/zv30/non-cmip/ACCESS-CM3/cm3-run-11-08-2025-25km-beta-om3-new-um-params/cm3-demo-datastore/cm3-demo-datastore.json'
plotfolder='/g/data/tm70/ek4684/access-om3-paper-1/notebooks/mkfigs_output4/'
dpi=300
### USER EDIT stop

import matplotlib as mpl
import os
# %matplotlib inline
mpl.rcParams['figure.dpi']= dpi

os.makedirs(plotfolder, exist_ok=True)

 # a similar cell under this means it's being run in batch
print("ESM datastore path: ",esm_file)
print("Plot folder path: ",plotfolder)
# Out:
# ESM datastore path:  /g/data/zv30/non-cmip/ACCESS-CM3/cm3-run-11-08-2025-25km-beta-om3-new-um-params/cm3-demo-datastore/cm3-demo-datastore.json
# Plot folder path:  /g/data/tm70/ek4684/access-om3-paper-1/notebooks/mkfigs_output4/

# %%
import xarray as xr
import cf_xarray as cfxr
import intake
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
from distributed import Client
import numpy as np

# %%
client = Client(threads_per_worker=1)
print(client.dashboard_link)
# Out:
# /proxy/40699/status
# 2025-10-14 12:06:03,960 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:44095' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'_delayed_open_ds-fcd5cda5-044b-406a-873a-6a8e456ef616', '_delayed_open_ds-e0c4d434-5c34-4c91-b64b-1760fe1fd5af', '_delayed_open_ds-ed6c89cd-6084-4d21-a52b-4e646954ab7b', '_delayed_open_ds-fe1495f4-bf0e-463a-9099-2bbda18a262e', '_delayed_open_ds-e4f1fd0b-e0ef-4f98-990e-20789281d5a9', '_delayed_open_ds-f7219d00-29dc-4a99-b3ad-8c35c882305a', '_delayed_open_ds-ebffc6dc-72f8-45be-a716-60a2142dec92', '_delayed_open_ds-d909b0a7-c33f-413e-9b2a-701332aa969d', '_delayed_open_ds-e1164b92-b7ef-4cd0-9925-cd8bf769d187', '_delayed_open_ds-f21e0565-7d47-4efc-9624-baec72477b24', '_delayed_open_ds-d1887a83-1981-4ffe-ab2f-18f92d37c1ba', '_delayed_open_ds-c84ab52b-5da0-4902-94e3-4e33f89ed321', '_delayed_open_ds-ed2a16d1-5516-4bbd-be58-0130aa21037e', '_delayed_open_ds-d7a34f35-d287-4e1b-9da3-ef88fc601766', '_delayed_open_ds-f968268e-b1c8-4ac3-a413-dbe71ee82b25', '_delayed_open_ds-c94ffb18-0528-4158-9aa8-02069664dab4', '_delayed_open_ds-c910f23b-0763-4665-b7cd-a5b80f40b84b', '_delayed_open_ds-c40405d0-d028-475c-8e1d-233c40a10426', '_delayed_open_ds-c6074652-b33b-4ea0-9776-e40fb94683f1', '_delayed_open_ds-d389ac60-f881-4cac-a69c-147687df35bb', '_delayed_open_ds-f3cac165-1066-4460-b7bc-c67b8f53a95e', '_delayed_open_ds-d99c0435-ae03-456d-afc1-1187e82353f9', '_delayed_open_ds-fdbf03a0-2f24-4350-bba4-c0192cd912d9', '_delayed_open_ds-f50fc52b-16d4-43f4-badf-00edd21fecc3', '_delayed_open_ds-e54f9d67-42a9-4bc8-93f5-4e2b31efad99', '_delayed_open_ds-daadc73b-8b
880d8c1', '_delayed_open_ds-c97f81ec-480f-47b4-a598-13d59fe441d5', '_delayed_open_ds-f89418ac-69fa-4df2-a935-65466294cd98', '_delayed_open_ds-e3ea386c-19c8-4268-bb17-f7ae5a47409c', '_delayed_open_ds-f22f6087-a187-4c9c-8c74-ecccfbd06d8f', '_delayed_open_ds-ed4d21b5-1dd5-459e-9eb4-e399212744d4', '_delayed_open_ds-d0b59793-a218-4e87-908d-1b0fe0cabecb', '_delayed_open_ds-c9155cd9-094d-4ff0-a239-766946067b74', '_delayed_open_ds-c6d616f8-d94e-4d7f-8e65-0ff04a110757', '_delayed_open_ds-cf50159b-ff02-4794-b7af-a11335014809', '_delayed_open_ds-fd982810-8132-4ac7-8984-e2a3a5be6722', '_delayed_open_ds-eba3f46e-6758-4be0-894d-982d4e47c4ea', '_delayed_open_ds-e727109c-0a00-4f06-910f-a4b2e3324143', '_delayed_open_ds-e5c1fe0e-7911-4eb5-a815-aa1f7ea58b48', '_delayed_open_ds-c81f2e92-5330-4291-8e20-c74dbb9518da', '_delayed_open_ds-c834497f-4524-404f-abad-41023d702827', '_delayed_open_ds-c422c559-750b-4fd7-a30e-171194b8e526', '_delayed_open_ds-d0e5c493-55d9-4055-9aec-197b0dbeeced', '_delayed_open_ds-fa9f7cb3-e99e-4bf6-8c42-a705f34df2fa', '_delayed_open_ds-f9c5ceca-2cda-4a78-b228-78529b008915', '_delayed_open_ds-e1433529-679e-4d8d-9784-b32aa42ef230', '_delayed_open_ds-fdb931d2-035e-4b41-b25d-a466c42b3986', '_delayed_open_ds-ff5cd37a-2a87-4607-a200-f553a3fdab59', '_delayed_open_ds-da73d828-1534-4693-85ef-30eb591176ac', '_delayed_open_ds-dd9b8bf5-d8e6-4e52-95b1-e5463a15e58f', '_delayed_open_ds-dae7f8ba-e70d-4d7d-8760-b079af253729', '_delayed_open_ds-f40ecf54-f605-4635-9c91-47f718a7064b'} (stimulus_id='handle-worker-cleanup-1760403963.9 ...

# %%
#datastore_path = "/g/data/ol01/access-om3-output/access-om3-025/MC_25km_jra_ryf-1.0-beta/experiment_datastore.json"
COLUMNS_WITH_ITERABLES = [
        "variable",
        "variable_long_name",
        "variable_standard_name",
        "variable_cell_methods",
        "variable_units"
]

datastore = intake.open_esm_datastore(
    esm_file,
    columns_with_iterables=COLUMNS_WITH_ITERABLES
)

# %%
def available_variables(datastore):
    """Return a pandas dataframe summarising the variables in a datastore"""
    variable_columns = [col for col in datastore.df.columns if "variable" in col]
    return (
        datastore.df[variable_columns]
        .explode(variable_columns)
        .drop_duplicates()
        .set_index("variable")
        .sort_index()
    )

# %%
datastore.df.realm.unique()
# Out:
# array(['atmos', 'seaIce', 'ocean'], dtype=object)

# %%
datastore_filtered = datastore.search(realm="atmos", frequency="1mon")

for col in COLUMNS_WITH_ITERABLES:
    datastore_filtered.df[col] = datastore_filtered.df[col].astype("object").map(lambda x: list(map(str, x)))

df = available_variables(datastore_filtered)
df.index
# Out:
# Index(['fld_s00i004', 'fld_s00i010', 'fld_s00i012', 'fld_s00i023',
#        'fld_s00i024', 'fld_s00i025', 'fld_s00i028', 'fld_s00i029',
#        'fld_s00i031', 'fld_s00i032',
#        ...
#        'rho_level_height', 'sigma_rho', 'sigma_theta', 'sigma_theta_0',
#        'sigma_theta_1', 'sigma_theta_2', 'theta_level_height',
#        'theta_level_height_0', 'theta_level_height_1', 'theta_level_height_2'],
#       dtype='object', name='variable', length=245)

# %%
# df[df.variable_long_name.apply(lambda name: 'ice area' in name.lower())]

# %% [markdown]
# ## Load ocean and atmosphere areas

# %%
wet = datastore.search(variable="wet").to_dask().compute()
areacello = datastore.search(variable="areacello").to_dask().compute()

areacello = (areacello.areacello * (wet.wet == 1.0))

# %%
EARTH_RADIUS = 6371229.0
nlon, nlat = 192, 144
dx = 360 / nlon
dy = 180 / nlat

element_lat = (np.arange(nlat) + 0.5) * dy  - 90
element_lat = element_lat[:, None] * np.ones(nlon)[None, :]

pi_over_180 = np.pi / 180
element_areas = dx * pi_over_180 * (
  np.sin((element_lat + 0.5 * dy) * pi_over_180) - np.sin((element_lat - 0.5 * dy) * pi_over_180)
)

areacella = element_areas * EARTH_RADIUS**2

total_ocn_fraction = areacello.sum().data / areacella.sum()
# Out:
# 0.7066920555972319

# %% [markdown]
# ## Ocean time series

# %% [markdown]
# ### Ocean heatflux

# %%
ocean_heatflux = datastore.search(variable="net_heat_coupler", frequency="1mon").to_dask(
    xarray_open_kwargs = dict(
        chunks={"yh": -1, "xh": -1}, # Good for spatial operations, but not temporal
        decode_timedelta=True
    )
).net_heat_coupler

# %%
# area weighted average of ocean heatflux
# average over entire earth for comparison with TOA
avg_ocean_heatflux = ocean_heatflux.weighted(areacello.fillna(0)).mean(dim=('yh', 'xh')).compute() * total_ocn_fraction

# %%
N = 12
rolling_avg = np.convolve(avg_ocean_heatflux, np.ones(N) / N, mode='valid')

plt.title('Global average heat flux into ocean (12 month rolling average)')
plt.plot(np.arange(len(rolling_avg)) / 12, rolling_avg)
plt.ylabel('Heat flux (W/m$^2$)')
plt.xlabel('Years')
# Out:
# Text(0.5, 0, 'Years')

# %% [markdown]
# ### SST

# %%
sst = datastore.search(variable="tos", frequency="1mon").to_dask(
    xarray_open_kwargs = dict(
        chunks={"yh": -1, "xh": -1}, # Good for spatial operations, but not temporal
        decode_timedelta=True
    )
).tos

# %%
# area weighted average of SST
avg_sst = sst.weighted(areacello.fillna(0)).mean(dim=('yh', 'xh')).compute()

# %%
N = 12
rolling_avg = np.convolve(avg_sst, np.ones(N) / N, mode='valid')

plt.title('Average SST (12 month rolling average)')
plt.plot(np.arange(len(rolling_avg)) / 12, rolling_avg)
plt.ylabel('Heat flux (W/m$^2$)')
plt.xlabel('Years')
# Out:
# Text(0.5, 0, 'Years')

# %% [markdown]
# ## Ice time series

# %%
ice_fraction = datastore.search(variable="aice_m", frequency="1mon")

# %% [markdown]
# ## Atmosphere time series

# %%
sw_toa = datastore.search(variable="fld_s01i208", frequency="1mon").to_dask()

# %%
lw_out = datastore.search(variable="fld_s02i205", frequency="1mon").to_dask()

# %%
sw_in = datastore.search(variable="fld_s01i207", frequency="1mon").to_dask()
